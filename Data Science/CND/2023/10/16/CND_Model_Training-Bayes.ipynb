# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("./data/CNDtrain.csv")

# %%
df.head()
# Out:
#                   fileName                                          MessageID  \
# 0  CN0CN7X8FCP0074B02FNA10  SWC1902 RAC0182 LOG007 DIS001 HWC2005 SEC0031 ...
# 1  CN0CN7X8FCP0074H032SA10  SWC1902 RAC0182 LOG007 DIS001 HWC2005 SEC0031 ...
# 2  CN0CN7X8FCP0078I00KUA10  SWC1902 RAC0182 LOG007 DIS001 HWC2005 SEC0031 ...
# 3  CN0CN7X8FCP0059801KWA10  SWC1902 RAC0182 LOG007 DIS001 HWC2005 SEC0031 ...
# 4  CN0KX11MFCP0081900A3A10  SWC1902 RAC0182 LOG007 DIS001 HWC2005 SEC0031 ...
#
#    CND
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
df.tail()
# Out:
#                     fileName  \
# 402  CN08CYF7FCP0086U0297A04
# 403  CN072T6DFCP0065I00UZA10
# 404  CN0923K0FCP0088N00E2A00
# 405  CN0923K0FCP0091401CNA00
# 406  CN00WGD1FCP0087I01ICA04
#
#                                              MessageID  CND
# 402  SYS1003 UEFI0061 UEFI0062 UEFI0065 SYS1003 SYS...    0
# 403  SYS1003 LOG007 UEFI0061 UEFI0062 SYS1001 SYS10...    0
# 404  SYS1003 UEFI0061 UEFI0062 UEFI0064 SYS1003 SYS...    0
# 405  SYS1003 UEFI0061 UEFI0062 SYS1003 SYS1001 RAC0...    0
# 406  SYS1003 UEFI0157 SYS1003 SYS1001 SYS1000 SYS10...    0

# %%
# df_test = pd.read_csv("./data/CNDtest.csv") 

df_test = pd.read_csv("./data/CND2023.csv")

# %%
import numpy as np
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt

# %%
trancatedSVD = TruncatedSVD(n_components=2, random_state=42)

# %%
df.groupby(['CND'])['CND'].count()
# Out:
# CND
# 0    213
# 1    194
# Name: CND, dtype: int64

# %%
df_test.groupby(['CND'])['CND'].count()
# Out:
# CND
# 0    17
# 1    10
# Name: CND, dtype: int64

# %%
X_train, X_test, y_train, y_test = df["MessageID"], df_test["MessageID"], df["CND"], df_test["CND"]

# %%
vectorizer = TfidfVectorizer(
    encoding="uft-8",
    decode_error="ignore"
)

# %%
# X_train_vec = vectorizer.fit_transform(X_train)

# %%
vectorizer_dir = f'./model/tfidf_train.joblib'

# %%
from joblib import dump, load
vectorizer = load(vectorizer_dir)

# %%
X_train_vec = vectorizer.transform(X_train)

# %%
X_test_vec = vectorizer.transform(X_test)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['amp0302', 'amp0303', 'amp0305', 'asr0000', 'asr0001', 'bar001',
#        'bar002', 'bar003', 'bar004', 'bar005', 'bar006', 'bar007',
#        'bar059', 'bar060', 'bar061', 'bar062', 'bar063', 'bar064',
#        'bar065', 'bar099', 'bar103', 'bat0000', 'bat0001', 'bat0002',
#        'bat0015', 'bat0016', 'bat0017', 'bat1008', 'bat1009', 'bat1025',
#        'bat1029', 'bat1033', 'cpu0000', 'cpu0001', 'cpu0005', 'cpu0010',
#        'cpu0012', 'cpu0016', 'cpu0704', 'cpu9000', 'cpua0023', 'ctl1',
#        'ctl100', 'ctl103', 'ctl104', 'ctl105', 'ctl106', 'ctl107',
#        'ctl108', 'ctl109', 'ctl11', 'ctl110', 'ctl111', 'ctl129', 'ctl13',
#        'ctl34', 'ctl35', 'ctl37', 'ctl38', 'ctl41', 'ctl48', 'ctl57',
#        'ctl75', 'ctl97', 'diag0000', 'diag0114', 'diag0125', 'diag0141',
#        'diag0142', 'diag0251', 'diag0415', 'diag8007', 'diag8170',
#        'dis001', 'dis002', 'dis003', 'dis004', 'dis010', 'dis111',
#        'dis115', 'dkm0001', 'enc18', 'enc24', 'enc26', 'enc40', 'fan0000',
#        'fan0001', 'fan0005', 'fan0028', 'fan0029', 'fan0030', 'fan1000',
#        'fc102', 'fc103', 'gmgr0001', 'gmgr0002', 'gmgr0005', 'gmgr0011',
#        'gmgr0033', 'hwc0010', 'hwc0013', 'hwc0017', 'hwc1000', 'hwc1001',
#        'hwc2002', 'hwc2003', 'hwc2004', 'hwc2005', 'hwc9004', 'ipa0100',
#        'ism0004', 'ism0007', 'ism0026', 'ism0047', 'ism0049', 'ism0050',
#        'jcp001', 'jcp002', 'jcp027', 'jcp036', 'jcp037', 'jcp038',
#        'jcp040', 'jcp042', 'jcp045', 'jcp046', 'lc0100', 'lc0101',
#        'lic201', 'lic202', 'lic207', 'lic208', 'lic209', 'lic210',
#        'lic211', 'log006', 'log007', 'log008', 'log009', 'log201',
#        'mem0000', 'mem0001', 'mem0701', 'mem0702', 'mem8000', 'mem9072',
#        'nic100', 'nic101', 'osd062', 'osd063', 'osd064', 'osd065',
#        'ose0001', 'ose0003', 'ose1002', 'pci1308', 'pci1310', 'pci1318',
#        'pci1348', 'pci1360', 'pci2000', 'pci3008', 'pci3014', 'pci3018',
#        'pci3030', 'pdr10', 'pdr1000', 'pdr1001', 'pdr1016', 'pdr1017',
#        'pdr105', 'pdr106', 'pdr107', 'pdr108', 'pdr11', 'pdr13', 'pdr15',
#        'pdr16', 'pdr26', 'pdr3', 'pdr38', 'pdr4', 'pdr41', 'pdr5',
#        'pdr50', 'pdr54', 'pdr6', 'pdr60', 'pdr61', 'pdr63', 'pdr64',
#        'pdr77', 'pdr8', 'pdr87', 'pdr88', 'pfm0002', 'pfm0004', 'pow001',
#        'pr1', 'pr10', 'pr11', 'pr17', 'pr18', 'pr19', 'pr2', 'pr3',
#        'pr36', 'pr4', 'pr6', 'pr7', 'pr8', 'pr9', 'pst0089', 'pst0090',
#        'pst0091', 'pst0128', 'pst0129', 'pst0208', 'pst0209', 'pst0256',
#        'psu0000', 'psu0001', 'psu0003', 'psu0006', 'psu0017', 'psu0019',
#        'psu0022', 'psu0034', 'psu0035', 'psu0036', 'psu0037', 'psu0038',
#        'psu0800', 'psu0802', 'psua0016', 'pwr1000', 'pwr1006', 'pwr2260',
#        'pwr2262', 'pwr2263', 'pwr2264', 'pwr2265', 'pwr2267', 'pwr2269',
#        'pwr2270', 'pwr2271', 'pwr2400', 'pwr2402', 'pwr2403', 'pwr8507',
#        'rac0181', 'rac0182', 'rac025', 'rac0560', 'rac0701', 'rac0702',
#        'rac0703', 'rac0704', 'rac0705', 'rac0708', 'rac0715', 'rac0716',
#        'rac0717', 'rac0718', 'rac0719', 'rac0720', 'rac0721', 'rac0724',
#        'rac1136', 'rac1137', 'rac1195', 'rac1197', 'rac802', 'rac803',
#        'rac804', 'rac937', 'rac938', 'rdu0001', 'rdu0002', 'rdu0011',
#        'rdu0012', 'red001', 'red002', 'red003', 'red004', 'red006',
#        'red007', 'red008', 'red014', 'red023', 'red025', 'red026',
#        'red029', 'red030', 'red033', 'red035', 'red036', 'red038',
#        'red040', 'red052', 'red054', 'red055', 'red058', 'red063',
#        'red064', 'red068', 'red097', 'red098', 'red100', 'red110',
#        'red111', 'rfl2002', 'rfl2003', 'rfl2004', 'rfla2001', 'rrdu0001',
#        'rrdu0002', 'rrdu0004', 'rrdu0006', 'rrdu0007', 'sec0031',
#        'sec0032', 'sec0033', 'sec0034', 'sec0700', 'sel0004', 'sel0014',
#        'sel1514', 'sel9901', 'sel9902', 'srv001', 'srv002', 'srv003',
#        'srv005', 'srv006', 'srv007', 'srv008', 'srv009', 'srv010',
#        'srv011', 'srv012', 'srv013', 'srv014', 'srv015', 'srv016',
#        'srv018', 'srv019', 'srv021', 'srv022', 'srv042', 'srv050',
#        'srv051', 'srv052', 'srv055', 'srv057', 'srv059', 'srv072',
#        'srv074', 'srv075', 'srv076', 'srv077', 'srv078', 'srv082',
#        'srv087', 'srv088', 'srv089', 'srv090', 'srv092', 'srv093',
#        'srv096', 'srv097', 'srv098', 'srv099', 'srv100', 'srv103',
#        'srv105', 'srv106', 'srv107', 'srv108', 'srv124', 'srv135',
#        'srv137', 'ssd0001', 'stor0502', 'stor0503', 'stor0504', 'sup0507',
#        'sup0511', 'sup0513', 'sup0516', 'sup0517', 'sup0518', 'sup0525',
#        'sup0535', 'sup0536', 'sup0538', 'sup1901', 'sup1903', 'sup1904',
#        'sup1905', 'sup1906', 'sup1911', 'swc0001', 'swc0015', 'swc0018',
#        'swc0024', 'swc0032', 'swc0057', 'swc0062', 'swc0066', 'swc0069',
#        'swc0070', 'swc0071', 'swc0072', 'swc0076', 'swc0088', 'swc0090',
#        'swc1901', 'swc1902', 'swc1909', 'swc1910', 'swc1911', 'swc1912',
#        'swc1913', 'swc1915', 'swc1916', 'swc1922', 'swc1925', 'swc5008',
#        'swu001', 'sys015', 'sys017', 'sys018', 'sys032', 'sys033',
#        'sys035', 'sys036', 'sys042', 'sys043', 'sys044', 'sys045',
#        'sys047', 'sys053', 'sys055', 'sys057', 'sys059', 'sys060',
#        'sys061', 'sys067', 'sys069', 'sys071', 'sys072', 'sys085',
#        'sys092', 'sys093', 'sys094', 'sys1000', 'sys1001', 'sys1003',
#        'sys111', 'sys122', 'sys139', 'sys141', 'sys142', 'sys143',
#        'sys144', 'sys146', 'sys148', 'sys149', 'sys150', 'sys151',
#        'sys153', 'sys156', 'sys157', 'sys160', 'sys161', 'sys162',
#        'sys163', 'sys165', 'sys166', 'sys167', 'sys173', 'sys176',
#        'sys178', 'sys179', 'sys180', 'sys181', 'sys185', 'sys186',
#        'sys187', 'sys191', 'sys195', 'sys198', 'sys200', 'sys201',
#        'sys226', 'sys252', 'sys261', 'sys278', 'tmp0118', 'tmp0120',
#        'tmp0121', 'tmp0123', 'tmp0203', 'tmp0205', 'tmp8503', 'uefi0001',
#        'uefi0004', 'uefi0011', 'uefi0012', 'uefi0019', 'uefi0020',
#        'uefi0021', 'uefi0023', 'uefi0026', 'uefi0031', 'uefi0033',
#        'uefi0034', 'uefi0035', 'uefi0047', 'uefi0050', 'uefi0051',
#        'uefi0052', 'uefi0056', 'uefi0057', 'uefi0058', 'uefi0059',
#        'uefi0060', 'uefi0061', 'uefi0062', 'uefi0064', 'uefi0065',
#        'uefi0066', 'uefi0067', 'uefi0069', 'uefi0071', 'uefi0073',
#        'uefi0074', 'uefi0075', 'uefi0076', 'uefi0077', 'uefi0078',
#        'uefi0079', 'uefi0081', 'uefi0082', 'uefi0098', 'uefi0103',
#        'uefi0104', 'uefi0106', 'uefi0107', 'uefi0108', 'uefi0109',
#        'uefi0110', 'uefi0115', 'uefi0116', 'uefi0119', 'uefi0120',
#        'uefi0121', 'uefi0122', 'uefi0130', 'uefi0134', 'uefi0135',
#        'uefi0136', 'uefi0138', 'uefi0140', 'uefi0141', 'uefi0144',
#        'uefi0157', 'uefi0252', 'uefi0256', 'uefi0264', 'uefi0281',
#        'uefi0285', 'uefi0296', 'uefi0297', 'uefi0298', 'uefi0299',
#        'uefi0305', 'uefi0306', 'uefi0323', 'uefi0326', 'uefi0330',
#        'uefi0331', 'uefi0339', 'uefi0344', 'usr0008', 'usr0030',
#        'usr0031', 'usr0032', 'usr0034', 'usr0150', 'usr0151', 'usr0152',
#        'usr0170', 'usr0171', 'usr0172', 'usr0173', 'usr0174', 'usr0175',
#        'usr0176', 'usr0183', 'usr0184', 'usr0200', 'usr0201', 'usr0206',
#        'usr0207', 'usr0208', 'usr0210', 'usr106', 'usr107', 'usr8514',
#        'usr8515', 'vdr11', 'vdr15', 'vdr2', 'vdr21', 'vdr23', 'vdr30',
#        'vdr31', 'vdr32', 'vdr33', 'vdr34', 'vdr35', 'vdr38', 'vdr4',
#        'vdr41', 'vdr44', 'vdr47', 'vdr5', 'vdr51', 'vdr52', 'vdr53',
#        'vdr56', 'vdr58', 'vdr60', 'vdr7', 'vdr8', 'vdr9', 'vdr93',
#        'vfla1000', 'vlt0204', 'vlt0205', 'vlt0304', 'vlt0305', 'vme0001',
#        'vme0002', 'vme0005', 'vme0006', 'vme0007', 'vme0008', 'wrk0001'],
#       dtype=object)

# %%
len(vectorizer.get_feature_names_out())
# Out:
# 651

# %%
nb_clf = MultinomialNB()

# %%
param_grid = {
    "alpha": [0.1, 0.5, 1.0],
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=nb_clf, param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=-1)

# %%
grid_search.fit(X_train_vec, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MultinomialNB(), n_jobs=-1,
#              param_grid={'alpha': [0.1, 0.5, 1.0]}, scoring='accuracy')

# %%
grid_search.cv_results_
# Out:
# {'mean_fit_time': array([0.00339532, 0.00283279, 0.00286741]),
#  'std_fit_time': array([0.00058837, 0.00044446, 0.00062684]),
#  'mean_score_time': array([0.00110025, 0.000951  , 0.00096874]),
#  'std_score_time': array([0.00019455, 0.00012752, 0.00021764]),
#  'param_alpha': masked_array(data=[0.1, 0.5, 1.0],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.1}, {'alpha': 0.5}, {'alpha': 1.0}],
#  'split0_test_score': array([0.7195122 , 0.7195122 , 0.69512195]),
#  'split1_test_score': array([0.65853659, 0.63414634, 0.65853659]),
#  'split2_test_score': array([0.60493827, 0.56790123, 0.55555556]),
#  'split3_test_score': array([0.54320988, 0.5308642 , 0.45679012]),
#  'split4_test_score': array([0.5308642 , 0.51851852, 0.5308642 ]),
#  'mean_test_score': array([0.61141223, 0.5941885 , 0.57937368]),
#  'std_test_score': array([0.07083469, 0.07447092, 0.08673134]),
#  'rank_test_score': array([1, 2, 3], dtype=int32)}

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
print(best_params, best_score)
# Out:
# {'alpha': 0.1} 0.6114122252333634

# %%
model_dir = f'./model/{grid_search.best_estimator_.__class__.__name__}.joblib'

# %%
from joblib import dump, load
dump(grid_search.best_estimator_, model_dir)
# Out:
# ['./model/MultinomialNB.joblib']

# %%
clf = load(model_dir)

# %%
X_train_pred = clf.predict(X_train_vec)

# %%
X_test_pred = clf.predict(X_test_vec)

# %%
X_train_acc = accuracy_score(y_train, X_train_pred)

# %%
X_test_acc = accuracy_score(y_test, X_test_pred)

# %%
X_train_acc
# Out:
# 0.7714987714987716

# %%
X_test_acc
# Out:
# 0.6296296296296297

# %%
# Fit and transform your data
reduced_data = trancatedSVD.fit_transform(X_train_vec)

# %%
reduced_data_test = trancatedSVD.transform(X_test_vec)

# %%
trancatedSVD.explained_variance_ratio_
# Out:
# array([0.03035716, 0.13155361])

# %%
# https://www.analyticsvidhya.com/blog/2018/10/stepwise-guide-topic-modeling-latent-semantic-analysis/

# %%
from matplotlib.colors import ListedColormap
from sklearn.inspection import DecisionBoundaryDisplay
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=y_train, cmap=cm_bright, alpha=0.2)
plt.scatter(reduced_data_test[:, 0], reduced_data_test[:, 1], c=y_test, cmap=cm_bright, marker="x")
plt.legend(["train", "test"])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Data in Lower Dimensions (2D)')
plt.text(0.95, -0.75, 'by You Sen (Ethan) Wang.',
             fontsize=10, color='gray',
             ha='right', va='bottom', alpha=0.75)
plt.savefig("./charts/train vs test.png")
plt.show()

# %%
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=X_train_pred, cmap=cm_bright, alpha=0.2)
plt.scatter(reduced_data_test[:, 0], reduced_data_test[:, 1], c=X_test_pred, cmap=cm_bright, marker="x")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Data in Lower Dimensions (2D)')
plt.show()

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix


cm = confusion_matrix(y_test, X_test_pred)

cm_display = ConfusionMatrixDisplay(cm).plot()
plt.title(grid_search.best_estimator_.__class__.__name__)
plt.savefig(f"./charts/{grid_search.best_estimator_.__class__.__name__}Confusion_Matrix.png")

# %%
import matplotlib.pyplot as plt
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=y_train, cmap=cm_bright, alpha=0.3)
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=X_train_pred, cmap=cm_bright, marker="x")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Train Data in Lower Dimensions (2D)')
plt.legend(["actual", "prediction"])
plt.text(0.95, -0.75, 'by You Sen (Ethan) Wang.',
             fontsize=10, color='gray',
             ha='right', va='bottom', alpha=0.75)
plt.savefig(f"./charts/{grid_search.best_estimator_.__class__.__name__}train_actual_vs_pred.png")
plt.show()

# %%
import matplotlib.pyplot as plt
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

plt.scatter(reduced_data_test[:, 0], reduced_data_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.3)
plt.scatter(reduced_data_test[:, 0], reduced_data_test[:, 1], c=X_test_pred, cmap=cm_bright, marker="x")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Test Data in Lower Dimensions (2D)')
plt.legend(["actual", "prediction"])
plt.text(0.75, -0.6, 'by You Sen (Ethan) Wang.',
             fontsize=10, color='gray',
             ha='right', va='bottom', alpha=0.75)
plt.savefig(f"./charts/{grid_search.best_estimator_.__class__.__name__}test_actual_vs_pred.png")
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay
ax = plt.gca()
rfc_disp = RocCurveDisplay.from_estimator(clf, X_test_vec, y_test, ax=ax, alpha=0.8)
rfc_disp.plot(ax=ax, alpha=0.8)

# %%
from sklearn.metrics import f1_score
f1_score(y_test, X_test_pred)
# Out:
# 0.28571428571428575

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, X_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75        17
#            1       0.50      0.20      0.29        10
#
#     accuracy                           0.63        27
#    macro avg       0.58      0.54      0.52        27
# weighted avg       0.60      0.63      0.58        27

# %%
pd.Series(grid_search.best_estimator_.feature_importances_, index = vectorizer.get_feature_names_out()).nlargest(12).plot(kind = 'barh',
                                                                               figsize = (10, 10),
                                                                              title = 'Feature importance from XGBoost').invert_yaxis();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 pd.Series(grid_search.best_estimator_.feature_importances_, index = vectorizer.get_feature_names_out()).nlargest(12).plot(kind = 'barh',
#       2                                                                                figsize = (10, 10),
#       3                                                                               title = 'Feature importance from XGBoost').invert_yaxis();
#
# AttributeError: 'MultinomialNB' object has no attribute 'feature_importances_'

# %%
# https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html#building-a-pipeline

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2023-10-12 16:17:23.228709: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-12 16:17:23.268716: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-12 16:17:23.270092: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-12 16:17:24.012420: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.3.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /usr/local/lib/python3.10/site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: sentence-transformers
# Note: you may need to restart the kernel to use updated packages.
